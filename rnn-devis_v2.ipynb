# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        print(filename)
        break
# Out:
# 4_non_alarm_151.wav
# 3_gas_alarm_106.wav
# 5_tsunami_alarm_345.wav
# 1_danger_alarm_531.wav
# 2_fire_alarm_223.wav

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-3]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 3000:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 3000

# %%
paths[:5]
# Out:
# ['/kaggle/input/alarm-dataset/dataset/alarm_non/4_non_alarm_151.wav',
#  '/kaggle/input/alarm-dataset/dataset/alarm_non/4_non_alarm_500.wav',
#  '/kaggle/input/alarm-dataset/dataset/alarm_non/4_non_alarm_232.wav',
#  '/kaggle/input/alarm-dataset/dataset/alarm_non/4_non_alarm_300.wav',
#  '/kaggle/input/alarm-dataset/dataset/alarm_non/4_non_alarm_316.wav']

# %%
labels[:10]
# Out:
# ['non', 'non', 'non', 'non', 'non', 'non', 'non', 'non', 'non', 'non']

# %%
## Create a dataframe
df = pd.DataFrame()
df['alarm'] = paths
df['label'] = labels
df.head(10)
# Out:
#                                                alarm label
# 0  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 1  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 2  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 3  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 4  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 5  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 6  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 7  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 8  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non
# 9  /kaggle/input/alarm-dataset/dataset/alarm_non/...   non

# %%
df['label'].value_counts()
# Out:
# non        600
# gas        600
# tsunami    600
# danger     600
# fire       600
# Name: label, dtype: int64

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, alarm):
    plt.figure(figsize=(10,4))
    plt.title(alarm, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, alarm):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(alarm, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz', cmap="coolwarm")
    plt.colorbar()

# %%
alarm = 'danger'
path = np.array(df['alarm'][df['label']==alarm])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, alarm)
spectogram(data, sampling_rate, alarm)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
alarm = 'fire'
path = np.array(df['alarm'][df['label']==alarm])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, alarm)
spectogram(data, sampling_rate, alarm)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
alarm = 'gas'
path = np.array(df['alarm'][df['label']==alarm])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, alarm)
spectogram(data, sampling_rate, alarm)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
alarm = 'non'
path = np.array(df['alarm'][df['label']==alarm])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, alarm)
spectogram(data, sampling_rate, alarm)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
alarm = 'tsunami'
path = np.array(df['alarm'][df['label']==alarm])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, alarm)
spectogram(data, sampling_rate, alarm)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <h1><b>Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=1, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['alarm'][0])
# Out:
# array([-5.0550897e+02,  1.6546466e+02, -5.9420238e+00,  6.2804611e+01,
#        -7.3137298e+00,  2.7928692e+01,  1.5049137e+01,  1.0620930e+01,
#        -5.4289341e+00,  8.6341896e+00,  3.7267036e+00, -1.1872705e+01,
#        -4.7836328e+00, -1.0370981e+01,  1.7688705e-01, -9.6857100e+00,
#        -6.8844676e-01, -1.0683152e+01, -6.8440614e+00, -4.6147308e+00,
#        -5.6772189e+00, -1.4276999e+00, -9.1719732e+00, -2.8043549e+00,
#        -6.8445773e+00, -3.4969652e+00, -4.8789425e+00, -1.3772950e+00,
#        -5.5471382e+00, -6.8145566e+00, -4.2641540e+00, -5.4021025e+00,
#        -8.8648224e-01, -2.7726290e+00, -9.4672930e-01, -3.7476606e+00,
#         1.3743389e+00, -2.7977254e+00, -5.2325006e+00, -3.3773026e+00],
#       dtype=float32)

# %%
X_mfcc = df['alarm'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-505.50897, 165.46466, -5.9420238, 62.80461, ...
# 1       [-577.16724, 114.86044, -30.015749, 31.902552,...
# 2       [-548.0349, 139.64154, -26.799358, 44.901432, ...
# 3       [-548.30054, 138.38304, -29.2764, 45.439137, -...
# 4       [-211.11302, 135.22124, -86.82089, 57.923264, ...
#                               ...
# 2995    [-242.89366, -74.477776, -59.336193, 84.83413,...
# 2996    [-231.92656, 64.075775, -91.395195, 67.2082, -...
# 2997    [-91.26608, 124.270065, -112.264275, 11.594888...
# 2998    [-230.28273, 40.10786, -93.93869, 75.16641, -5...
# 2999    [-442.15256, 44.109554, -81.152824, 61.85681, ...
# Name: alarm, Length: 3000, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (3000, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (3000, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (3000, 5)

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2)

# %%
print(X_train.shape,y_train.shape,X_validation.shape,y_validation.shape,X_test.shape,y_test.shape)
# Out:
# (2160, 40, 1) (2160, 5) (540, 40, 1) (540, 5) (300, 40, 1) (300, 5)

# %% [markdown]
# <h1><b>Model Creation

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(5, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# 2022-04-12 07:32:45.553486: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               264192
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 305,669
# Trainable params: 305,669
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
# history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)
# Out:
# 2022-04-12 07:32:50.084944: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/30
# 68/68 [==============================] - 9s 95ms/step - loss: 0.8134 - accuracy: 0.7019 - val_loss: 0.3096 - val_accuracy: 0.9056
# Epoch 2/30
# 68/68 [==============================] - 5s 74ms/step - loss: 0.2886 - accuracy: 0.9032 - val_loss: 0.1932 - val_accuracy: 0.9463
# Epoch 3/30
# 68/68 [==============================] - 5s 74ms/step - loss: 0.1784 - accuracy: 0.9477 - val_loss: 0.1310 - val_accuracy: 0.9648
# Epoch 4/30
# 68/68 [==============================] - 5s 78ms/step - loss: 0.1454 - accuracy: 0.9579 - val_loss: 0.1035 - val_accuracy: 0.9778
# Epoch 5/30
# 68/68 [==============================] - 5s 78ms/step - loss: 0.0830 - accuracy: 0.9736 - val_loss: 0.0881 - val_accuracy: 0.9741
# Epoch 6/30
# 68/68 [==============================] - 5s 80ms/step - loss: 0.1039 - accuracy: 0.9727 - val_loss: 0.0695 - val_accuracy: 0.9815
# Epoch 7/30
# 68/68 [==============================] - 6s 86ms/step - loss: 0.0653 - accuracy: 0.9782 - val_loss: 0.0881 - val_accuracy: 0.9815
# Epoch 8/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0414 - accuracy: 0.9894 - val_loss: 0.0981 - val_accuracy: 0.9778
# Epoch 9/30
# 68/68 [==============================] - 5s 75ms/step - loss: 0.0356 - accuracy: 0.9912 - val_loss: 0.0737 - val_accuracy: 0.9852
# Epoch 10/30
# 68/68 [==============================] - 5s 79ms/step - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.0874 - val_accuracy: 0.9815
# Epoch 11/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0402 - accuracy: 0.9880 - val_loss: 0.0905 - val_accuracy: 0.9778
# Epoch 12/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0411 - accuracy: 0.9884 - val_loss: 0.1199 - val_accuracy: 0.9778
# Epoch 13/30
# 68/68 [==============================] - 6s 86ms/step - loss: 0.0212 - accuracy: 0.9949 - val_loss: 0.0818 - val_accuracy: 0.9833
# Epoch 14/30
# 68/68 [==============================] - 5s 77ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.0936 - val_accuracy: 0.9833
# Epoch 15/30
# 68/68 [==============================] - 5s 77ms/step - loss: 0.0641 - accuracy: 0.9866 - val_loss: 0.0945 - val_accuracy: 0.9778
# Epoch 16/30
# 68/68 [==============================] - 6s 81ms/step - loss: 0.0400 - accuracy: 0.9866 - val_loss: 0.0740 - val_accuracy: 0.9889
# Epoch 17/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0241 - accuracy: 0.9944 - val_loss: 0.0718 - val_accuracy: 0.9870
# Epoch 18/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.0750 - val_accuracy: 0.9852
# Epoch 19/30
# 68/68 [==============================] - 6s 85ms/step - loss: 0.0093 - accuracy: 0.9986 - val_loss: 0.0761 - val_accuracy: 0.9907
# Epoch 20/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0885 - val_accuracy: 0.9852
# Epoch 21/30
# 68/68 [==============================] - 5s 74ms/step - loss: 0.0101 - accuracy: 0.9977 - val_loss: 0.0696 - val_accuracy: 0.9889
# Epoch 22/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0761 - val_accuracy: 0.9870
# Epoch 23/30
# 68/68 [==============================] - 5s 77ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.0979 - val_accuracy: 0.9852
# Epoch 24/30
# 68/68 [==============================] - 5s 76ms/step - loss: 0.0262 - accuracy: 0.9921 - val_loss: 0.1597 - val_accuracy: 0.9685
# Epoch 25/30
# 68/68 [==============================] - 6s 85ms/step - loss: 0.0636 - accuracy: 0.9838 - val_loss: 0.0863 - val_accuracy: 0.9833
# Epoch 26/30
# 68/68 [==============================] - 5s 75ms/step - loss: 0.0248 - accuracy: 0.9944 - val_loss: 0.0751 - val_accuracy: 0.9870
# Epoch 27/30
# 68/68 [==============================] - 5s 75ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.1034 - val_accuracy: 0.9870
# Epoch 28/30
# 68/68 [==============================] - 5s 78ms/step - loss: 0.0164 - accuracy: 0.9931 - val_loss: 0.1041 - val_accuracy: 0.9796
# Epoch 29/30
# 68/68 [==============================] - 5s 74ms/step - loss: 0.0417 - accuracy: 0.9894 - val_loss: 0.1322 - val_accuracy: 0.9741
# Epoch 30/30
# 68/68 [==============================] - 5s 74ms/step - loss: 0.0287 - accuracy: 0.9907 - val_loss: 0.1101 - val_accuracy: 0.9815

# %%
epochs = list(range(30))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
predict_x=model.predict(X_validation) 
classes_x=np.argmax(predict_x,axis=1)

y_pred = model.predict(X_validation)
y_test_class = np.argmax(y_validation, axis=1)
cf_matrix = confusion_matrix(y_test_class, classes_x)
print (cf_matrix)
# Out:
# [[100   0   0   2   0]
#  [  1  94   0   0   0]
#  [  0   0 117   1   0]
#  [  2   0   0 122   2]
#  [  2   0   0   0  97]]

# %%
#confusion matrix prediction of validation data
ax = sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, fmt='.2%', cmap='Blues')

ax.set_title('Confusion Matrix Validation Data\n\n');
ax.set_xlabel('Predicted Condition')
ax.set_ylabel('Actual Condition');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['1','2', '3', '4','5'])
ax.yaxis.set_ticklabels(['1','2', '3', '4','5'])
## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_class, classes_x))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       102
#            1       1.00      0.99      0.99        95
#            2       1.00      0.99      1.00       118
#            3       0.98      0.97      0.97       126
#            4       0.98      0.98      0.98        99
#
#     accuracy                           0.98       540
#    macro avg       0.98      0.98      0.98       540
# weighted avg       0.98      0.98      0.98       540
